# %%
import tkinter as tk

# 1. Create the main window object
root = tk.Tk()

# 2. Add some optional settings
root.title("My First Window")
root.geometry("400x300") # Width x Height

# 3. Add a widget (optional but keeps it from being empty)
label = tk.Label(root, text="Hello, Tkinter!")
label.pack()

# 4. Start the event loop
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[5], line 4
#       1 import tkinter as tk
#       3 # 1. Create the main window object
# ----> 4 root = tk.Tk()
#       6 # 2. Add some optional settings
#       7 root.title("My First Window")
#
# File /Software/users/modules/9/software/anaconda3/2023.03/lib/python3.10/tkinter/__init__.py:2299, in Tk.__init__(self, screenName, baseName, className, useTk, sync, use)
#    2297         baseName = baseName + ext
#    2298 interactive = False
# -> 2299 self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2300 if useTk:
#    2301     self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
